# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(n_samples=2000,n_features=2,centers=4,cluster_std=1.8,random_state=101)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='seismic')

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# when we are importing this model, under the hood, the model is performing the two steps for us: picking random
#     position for k and making that random position better by averaging it out

# %%
kmeans=KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[-9.34438237, -6.48824207],
#        [ 3.89159423,  6.79773467],
#        [-3.84452619,  7.87644616],
#        [ 0.4314781 ,  1.31760819]])

# %%
kmeans.labels_
# Out:
# array([0, 3, 0, ..., 0, 2, 2], dtype=int32)

# %%
fig, (ax1,ax2)= plt.subplots(1,2, sharey=True,figsize=(10,6))

ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='seismic')
